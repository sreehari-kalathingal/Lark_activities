# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics

# %% [markdown]
# # 1.Loading the dataset

# %% [markdown]
# # 2.Making Passenger-id the index column

# %%
df = pd.read_csv('c:/Users/Sreehari/Downloads/titanic_dataset.csv', index_col='PassengerId')
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# # 3. Checking the basic details of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # 4. Handling missing values

# %% [markdown]
# # a)Age

# %%
print('\nNumber of null values in age column: ', df['Age'].isnull().sum())
# Out:
# Number of null values in age column:  177

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df['median_age'] = df['Age'].fillna(df['Age'].median())
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#              median_age
# PassengerId
# 1                  22.0
# 2                  38.0
# 3                  26.0
# 4                  35.0
# 5                  35.0

# %%
sns.kdeplot(data=df[['Age', 'median_age']])
plt.show()

# %%
random_age_values = df['Age'].dropna().sample(df['Age'].isnull().sum())
random_age_values.index = df[df['Age'].isnull()].index
df['random_age'] = df['Age'].fillna(random_age_values)

# %%
sns.kdeplot(data=df[['Age', 'median_age', 'random_age']])
plt.show()

# %%
df['Age'].fillna(random_age_values, inplace=True)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df.drop(columns=['median_age', 'random_age'], inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# # b) Embarked

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
df['Embarked'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # c)cabin

# %%
df['Cabin'].isnull().sum()
# Out:
# 687

# %%
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Cabin'].fillna('N/A', inplace=True)

# %%
df['Cabin'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # 5. Handling Outliers

# %%
sns.boxplot(data=df[['Age', 'Fare', 'SibSp']], orient='h')
plt.show()

# %%
df_with_outliers = df.copy(deep=True)

# %%
def outlier_handling(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    q_limit = 1.5 * iqr
    upper_limit = q3 + q_limit
    lower_limt = q1 - q_limit
    outliers = data.loc[(data < lower_limt) ^ (data > upper_limit)].tolist()
    idx = data.loc[(data < lower_limt) ^ (data > upper_limit)].index.tolist()
    return outliers, idx

# %%
fare_outlier_list, fare_outlier_index = outlier_handling(df['Fare'])
age_outlier_list, age_outlier_index = outlier_handling(df['Age'])
sibsp_oulliers, sibsp_outlier_index = outlier_handling(df['SibSp'])

# %%
print(len(fare_outlier_index), len(age_outlier_index), len(sibsp_outlier_index))
# Out:
# 116 11 46

# %%
new_idx = sibsp_outlier_index + age_outlier_index + fare_outlier_index
len(new_idx)
# Out:
# 173

# %%
new_idx = set(new_idx)
new_idx
# Out:
# {2,
#  8,
#  17,
#  25,
#  28,
#  32,
#  34,
#  35,
#  51,
#  53,
#  60,
#  62,
#  63,
#  64,
#  69,
#  72,
#  73,
#  86,
#  89,
#  97,
#  103,
#  117,
#  119,
#  120,
#  121,
#  125,
#  140,
#  141,
#  152,
#  160,
#  165,
#  172,
#  177,
#  181,
#  183,
#  196,
#  202,
#  216,
#  219,
#  225,
#  230,
#  231,
#  234,
#  246,
#  257,
#  258,
#  259,
#  262,
#  263,
#  267,
#  269,
#  270,
#  276,
#  279,
#  291,
#  292,
#  298,
#  300,
#  306,
#  307,
#  308,
#  311,
#  312,
#  319,
#  320,
#  325,
#  326,
#  333,
#  335,
#  337,
#  338,
#  342,
#  367,
#  370,
#  374,
#  375,
#  376,
#  378,
#  381,
#  386,
#  387,
#  391,
#  394,
#  410,
#  412,
#  413,
#  436,
#  439,
#  446,
#  454,
#  481,
#  485,
#  486,
#  487,
#  494,
#  497,
#  498,
#  499,
#  505,
#  506,
#  521,
#  528,
#  538,
#  541,
#  542,
#  543,
#  545,
#  551,
#  558,
#  559,
#  582,
#  586,
#  588,
#  592,
#  610,
#  628,
#  631,
#  635,
#  642,
#  643,
#  646,
#  656,
#  660,
#  661,
#  666,
#  673,
#  680,
#  682,
#  684,
#  687,
#  690,
#  699,
#  701,
#  709,
#  717,
#  727,
#  731,
#  738,
#  742,
#  743,
#  746,
#  760,
#  764,
#  766,
#  780,
#  788,
#  790,
#  793,
#  803,
#  814,
#  820,
#  821,
#  825,
#  830,
#  836,
#  847,
#  850,
#  851,
#  852,
#  857,
#  864,
#  880}

# %%
len(new_idx)
# Out:
# 162

# %%
index_to_remove = list(new_idx)

# %%
len(index_to_remove)
# Out:
# 162

# %%
df.drop(index=index_to_remove, inplace=True)

# %%
df.shape
# Out:
# (729, 11)

# %% [markdown]
# # 6. Min-max scaling

# %%
df.drop('Name',axis=1,inplace=True)
df.drop('Ticket',axis=1,inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500   N/A
# 3                   1       3  female  26.0      0      0   7.9250   N/A
# 4                   1       1  female  35.0      1      0  53.1000  C123
# 5                   0       3    male  35.0      0      0   8.0500   N/A
# 6                   0       3    male  49.0      0      0   8.4583   N/A
#
#             Embarked
# PassengerId
# 1                  S
# 3                  S
# 4                  S
# 5                  S
# 6                  Q

# %%
df=pd.get_dummies(df)
df.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500           0
# 3                   1       3  26.0      0      0   7.9250           1
# 4                   1       1  35.0      1      0  53.1000           1
# 5                   0       3  35.0      0      0   8.0500           0
# 6                   0       3  49.0      0      0   8.4583           0
#
#              Sex_male  Cabin_A10  Cabin_A14  ...  Cabin_F2  Cabin_F33  \
# PassengerId                                  ...
# 1                   1          0          0  ...         0          0
# 3                   0          0          0  ...         0          0
# 4                   0          0          0  ...         0          0
# 5                   1          0          0  ...         0          0
# 6                   1          0          0  ...         0          0
#
#              Cabin_F38  Cabin_F4  Cabin_G6  Cabin_N/A  Cabin_T  Embarked_C  \
# PassengerId
# 1                    0         0         0          1        0           0
# 3                    0         0         0          1        0           0
# 4                    0         0         0          0        0           0
# 5                    0         0         0          1        0           0
# 6                    0         0         0          1        0           0
#
#              Embarked_Q  Embarked_S
# PassengerId
# 1                     0           1
# 3                     0           1
# 4                     0           1
# 5                     0           1
# 6                     1           0
#
# [5 rows x 97 columns]

# %%
y=df['Survived']
x=df.drop('Survived',axis=1)

# %%
x.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare  Sex_female  \
# count  729.000000  729.000000  729.000000  729.000000  729.000000  729.000000
# mean     2.459534   29.430960    0.278464    0.288066   17.150605    0.311385
# std      0.740374   13.356394    0.508812    0.755480   13.420518    0.463378
# min      1.000000    0.420000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   21.000000    0.000000    0.000000    7.895800    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000   11.500000    0.000000
# 75%      3.000000   37.000000    0.000000    0.000000   25.929200    1.000000
# max      3.000000   65.000000    2.000000    6.000000   65.000000    1.000000
#
#          Sex_male   Cabin_A10   Cabin_A14   Cabin_A16  ...    Cabin_F2  \
# count  729.000000  729.000000  729.000000  729.000000  ...  729.000000
# mean     0.688615    0.001372    0.001372    0.001372  ...    0.004115
# std      0.463378    0.037037    0.037037    0.037037  ...    0.064062
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000  ...    0.000000
# 75%      1.000000    0.000000    0.000000    0.000000  ...    0.000000
# max      1.000000    1.000000    1.000000    1.000000  ...    1.000000
#
#         Cabin_F33   Cabin_F38    Cabin_F4    Cabin_G6   Cabin_N/A     Cabin_T  \
# count  729.000000  729.000000  729.000000  729.000000  729.000000  729.000000
# mean     0.004115    0.001372    0.002743    0.005487    0.846365    0.001372
# std      0.064062    0.037037    0.052342    0.073921    0.360846    0.037037
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    1.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    1.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Embarked_C  Embarked_Q  Embarked_S
# count  729.000000  729.000000  729.000000
# mean     0.155007    0.094650    0.750343
# std      0.362160    0.292932    0.433112
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000
# 50%      0.000000    0.000000    1.000000
# 75%      0.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000
#
# [8 rows x 96 columns]

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
predictions=model.predict(x_test)
print('MSE is : ',mean_squared_error(y_test,predictions))
print('r squared value is : ',r2_score(y_test,predictions))
# Out:
# MSE is :  2.173141093417952e+20
# r squared value is :  -9.191007053035131e+20
